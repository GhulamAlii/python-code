# %% [markdown]
# # OPEN CV  Fundamentals

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
imgc = img.copy()
cv2.line(imgc,(100,300),(300,50),(255,255,0),5)
plt.imshow(imgc[...,::-1]);

# %%
imgc = img.copy()
cv2.circle(imgc,(100,63), 55, (25,0,0), -5)
plt.imshow(imgc[...,::-1]);

# %%
imgc = img.copy()
imgc2 = img.copy()
pts = np.array([[10,5],[100,200],[70,340],[300,300]]) #lets make a polygon of 4 p
cv2.polylines(imgc, [pts], True, (255,0,255), 5) # close this polygon
cv2.polylines(imgc2, [pts], False, (255,0,255), 5) # left this polygon open
plt.figure(figsize=[15,15])
plt.subplot(121);plt.imshow(imgc[:,:,::-1]);plt.title("Closed Polygon");
plt.subplot(122);plt.imshow(imgc2[:,:,::-1]);plt.title("Open Polygon");
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-20-f41b5b3c40cf> in <module>
#       5 cv2.polylines(imgc2, [pts], False, (255,0,255), 5) # left this polygon open
#       6 plt.figure(figsize=[15,15])
# ----> 7 plt.subplot(121);plt.imshow(imgc[:,:,::-1]);plt.title("Closed Polygon");
#       8 plt.subplot(122);plt.imshow(imgc2[:,:,::-1]);plt.title("Open Polygon");
#
# IndexError: too many indices for array: array is 2-dimensional, but 3 were indexed

# %%
#Initilize Video capture Object and points towards a video file
cap = cv2.VideoCapture('resource/testvid.mp4')
# If your capture was not properly initialized , then open it.
if not cap.isOpened():
    cap.open('media/M1/vtest.avi')

# Lets print the status of your Capture.
    print('Status:',cap.isOpened())
# Initilize a loop in which we will read video frame by frame
while(True):

# read frame by frame
    ret, frame = cap.read()
# if a frame is not read correctly or there are no more frames to be read the
    if not ret:
        break

# lets just convert this video in grayscale so we can say we are doing real t
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
# Show the frame we just read
    cv2.imshow('frame',gray)

# Wait for the specified milliseconds, before showing showing the next frame,
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
# Release the videocapture object
cap.release()
# Destroy the windows you created
cv2.destroyAllWindows()
