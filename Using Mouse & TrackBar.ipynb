# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
# img = cv2.imread('resource/pepsi.jpg',1)

# cv2.namedWindow('image')

# def drawshape(event,x,y,flags,userdata):
#     if event == cv2.EVENT_RBUTTONDOWN:
#         cv2.rectangle(img, pt1=(x,y), pt2=(x+50,y+50),color=(50,55,255),thickness=3)
#         cv2.putText(img, f"x={x},y={y}",(x,y), cv2.FONT_HERSHEY_SIMPLEX , 1, (55, 200, 134), 2, cv2.LINE_AA)
#     elif event == cv2.EVENT_LBUTTONDBLCLK: 
#         cv2.circle(img,(x,y),10,(255,0,0),-1)
#         cv2.putText(img, f"x={x},y={y}",(x, y), cv2.FONT_HERSHEY_SIMPLEX , 1, (55, 200, 134), 2, cv2.LINE_AA)

# cv2.setMouseCallback('image',drawshape)

# while True:
#     cv2.imshow('image',img)
    

#     if cv2.waitKey(50) & 0xFF == 27:
#         break
        
# cv2.destroyAllWindows()

# %%
img = np.zeros((512,512,3), np.uint8)
cv2.namedWindow('image')

def nothing(x): 
    pass

cv2.createTrackbar('color1','image',5,255,nothing)
cv2.createTrackbar('color2','image',5,255,nothing)
cv2.createTrackbar('color3','image',5,255,nothing)
# cv2.createTrackbar('thickness','image',-1,5,nothing)
def draw_circle(event,x,y,flags,param): 
    if event == cv2.EVENT_LBUTTONDBLCLK: 
        cv2.circle(img,(x,y),100,(color1,color2,color3),-1)

cv2.setMouseCallback('image',draw_circle)

while True:
    
    cv2.imshow('image',img)
    
#   radius = cv2.getTrackbarPos('Radius','image')
    color1 = cv2.getTrackbarPos("color1",'image')
    color2 = cv2.getTrackbarPos("color2",'image')
    color3 = cv2.getTrackbarPos("color3",'image')
    
    
    if cv2.waitKey(20) & 0xFF == ord('c') :
        img = np.ones((512,512,3), np.uint8)
    
    
    if cv2.waitKey(20) & 0xFF == 27 or cv2.getWindowProperty('image',cv2.WND_PROP_VISIBLE) < 1: 
        break
           
            
cv2.destroyAllWindows()

# %%
# %matplotlib notebook
# pic = cv2.imread('resource/pepsi.jpg',1)

# row,col,channel = pic.shape

# # pic[0:row,col//2:col] = 0

# plt.imshow(pic[...,::-1])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
pic = cv2.imread('resource/pepsi.jpg',1)

pic[435:1114,61:816] = 0

plt.imshow(pic)
